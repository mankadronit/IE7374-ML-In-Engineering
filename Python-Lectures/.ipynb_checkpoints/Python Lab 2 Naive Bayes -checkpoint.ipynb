# %% [markdown]
# ## Naive Bayes

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm as tqdm

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
from sklearn.preprocessing import normalize

from scipy.stats import norm

from random import choices

# %%
X, y = make_blobs(n_samples=10000, centers=2, n_features = 2, random_state = 1)

# %%
print(X.shape, y.shape)
print(X[:5])
print(y[:5])
# Out:
# (10000, 2) (10000,)
# [[-3.08389358  5.70067218]
#  [-8.80258525 -5.07389013]
#  [-1.68452735  5.22511143]
#  [-1.44683075  4.51471432]
#  [-3.36067232  3.22371079]]
# [0 1 0 0 0]

# %%
X = np.where(X > 0, 1, 0)

# %%
print(X.shape, y.shape)
print(X[:5])
print(y[:5])
# Out:
# (10000, 2) (10000,)
# [[0 1]
#  [0 0]
#  [0 1]
#  [0 1]
#  [0 1]]
# [0 1 0 0 0]

# %%
class NaiveBayes:
    
    def __init__(self, X, y, epsilon = 1, discrete = False):
        self.X = X
        self.y = y
        self.epsilon = epsilon
        self.discrete = discrete
        
        
    def trainTestSplit(self):
        self.X_train, self.X_test, self.y_train, self.y_test =  train_test_split(self.X, self.y, 
                                                                                 test_size = 0.3, random_state = 1)
        
        
    def fitDistribution(self, data):
        mu = np.mean(data)
        sigma = np.std(data)
        
        dist = norm(mu, sigma)
        return dist
    
    
    def probability(self, x, prior, label):
        
        if not self.discrete:
            dist1 = self.dist_X0y0 if label == 0 else self.dist_X0y1
            dist2 = self.dist_X1y0 if label == 0 else self.dist_X1y1
            
            return prior * dist1.pdf(x[0]) * dist2.pdf(x[1])
            #return prior * dist1.pdf(x[0]) * dist2.pdf(x[1])
        else:
            #print("PRIOR and DIST 1 and DIST 2: ", prior, dist1, dist2)
            ans = prior

            if label == 0:
                if x[0] == 0:
                    ans *= self.prob_X00y0
                elif x[0] == 1:
                    ans *= self.prob_X01y0

                if x[1] == 0:
                    ans *= self.prob_X10y0
                elif x[1] == 1:
                    ans *= self.prob_X11y0

            elif label == 1:
                if x[0] == 0:
                    ans *= self.prob_X00y1
                elif x[0] == 1:
                    ans *= self.prob_X01y1

                if x[1] == 0:
                    ans *= self.prob_X10y1
                elif x[1] == 1:
                    ans *= self.prob_X11y1

            return ans
                
    
    def runModel(self):
        self.trainTestSplit()
        
        self.X0_train = self.X_train[self.y_train == 0]
        self.X1_train = self.X_train[self.y_train == 1]
        
        # Calculate Priors
        self.prior_y0 = len(self.X0_train) / len(self.X_train)
        self.prior_y1 = len(self.X1_train) / len(self.X_train)
        
        
        if self.discrete:
            # X0 = 0, Y = 0
            self.prob_X00y0 = (self.X0_train[np.where(self.X0_train[:,0] == 0)].shape[0] + self.epsilon)/(len(self.X0_train) + 2*self.epsilon)
            # X0 = 1, Y = 0
            self.prob_X01y0 = (self.X0_train[np.where(self.X0_train[:,0] == 1)].shape[0] + self.epsilon)/(len(self.X0_train) + 2*self.epsilon)

            # X1 = 0, Y = 0
            self.prob_X10y0 = (self.X0_train[np.where(self.X0_train[:,1] == 0)].shape[0] + self.epsilon)/(len(self.X0_train) + 2*self.epsilon)
            # X1 = 1, Y = 0
            self.prob_X11y0 = (self.X0_train[np.where(self.X0_train[:,1] == 1)].shape[0] + self.epsilon)/(len(self.X0_train) + 2*self.epsilon)


            # X0 = 0, Y = 1
            self.prob_X00y1 = (self.X1_train[np.where(self.X1_train[:,0] == 0)].shape[0] + self.epsilon)/ (len(self.X1_train) + 2*self.epsilon)
            # X0 = 1, Y = 1
            self.prob_X01y1 = (self.X1_train[np.where(self.X1_train[:,0] == 1)].shape[0] + self.epsilon)/ (len(self.X1_train) + 2*self.epsilon)

            # X1 = 0, Y = 1
            self.prob_X10y1 = (self.X1_train[np.where(self.X1_train[:,1] == 0)].shape[0] + self.epsilon)/ (len(self.X1_train) + 2*self.epsilon)

            # X1 = 1, Y = 1
            self.prob_X11y1 = (self.X1_train[np.where(self.X1_train[:,1] == 1)].shape[0] + self.epsilon)/ (len(self.X1_train) + 2*self.epsilon)
        
        else:
        
            # Create PDFs for class 0
            self.dist_X0y0 = self.fitDistribution(self.X0_train[:, 0])
            self.dist_X1y0 = self.fitDistribution(self.X0_train[:, 1])

            # Create PDFs for class 1
            self.dist_X0y1 = self.fitDistribution(self.X1_train[:, 0])
            self.dist_X1y1 = self.fitDistribution(self.X1_train[:, 1])
        
        
    
    def predict(self):
        
        for sample, target in zip(self.X_test, self.y_test):
            py0 = self.probability(sample, self.prior_y0, label = 0)
            py1 = self.probability(sample, self.prior_y1, label = 1)
            
            print('P(y=0| %s) = %.3f' % (sample, py0*100))
            print('P(y=1| %s) = %.3f' % (sample, py1*100))
            
                
            print("Model predicted class {} and the truth was {} \n".format(np.argmax([py0*100, py1*100]), target))

# %%
nb = NaiveBayes(X, y)

# %%
nb.runModel()

# %%
nb.predict()
# Out:
# P(y=0| [-9.27061244 -3.19934372]) = 0.000
# P(y=1| [-9.27061244 -3.19934372]) = 4.671
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-8.61135164 -4.31237315]) = 0.000
# P(y=1| [-8.61135164 -4.31237315]) = 2.947
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.1957157  -4.22503894]) = 0.000
# P(y=1| [-9.1957157  -4.22503894]) = 5.625
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.45043443  -3.62184549]) = 0.000
# P(y=1| [-10.45043443  -3.62184549]) = 6.706
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-3.43415589  4.09426021]) = 1.566
# P(y=1| [-3.43415589  4.09426021]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.27663338  4.25755315]) = 6.332
# P(y=1| [-2.27663338  4.25755315]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.72042057  3.65838399]) = 5.875
# P(y=1| [-1.72042057  3.65838399]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.37620393  3.69783487]) = 4.680
# P(y=1| [-2.37620393  3.69783487]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.24532604  3.6537749 ]) = 5.428
# P(y=1| [-1.24532604  3.6537749 ]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.58812928  3.27372202]) = 4.113
# P(y=1| [-1.58812928  3.27372202]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.92245309 -5.43608777]) = 0.000
# P(y=1| [-9.92245309 -5.43608777]) = 2.657
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.03987891  -4.84050694]) = 0.000
# P(y=1| [-10.03987891  -4.84050694]) = 5.334
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.74876888  -4.46725331]) = 0.000
# P(y=1| [-10.74876888  -4.46725331]) = 5.165
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-0.26973395  4.41324015]) = 3.086
# P(y=1| [-0.26973395  4.41324015]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.45033358  -3.90453434]) = 0.000
# P(y=1| [-10.45033358  -3.90453434]) = 7.066
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.14156912  -2.95850549]) = 0.000
# P(y=1| [-10.14156912  -2.95850549]) = 4.798
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.24307516 -5.04866672]) = 0.000
# P(y=1| [-9.24307516 -5.04866672]) = 3.339
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.73703647  -3.89169007]) = 0.000
# P(y=1| [-10.73703647  -3.89169007]) = 5.934
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.83690092  -2.87802789]) = 0.000
# P(y=1| [-10.83690092  -2.87802789]) = 3.114
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.49021128  5.29843958]) = 3.695
# P(y=1| [-2.49021128  5.29843958]) = 0.000
# ...
#
# P(y=0| [-0.57514134  4.29639291]) = 4.414
# P(y=1| [-0.57514134  4.29639291]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-8.75827395 -6.23638063]) = 0.000
# P(y=1| [-8.75827395 -6.23638063]) = 0.289
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.49356221  5.73791314]) = 3.177
# P(y=1| [-1.49356221  5.73791314]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-12.63833179  -2.67625307]) = 0.000
# P(y=1| [-12.63833179  -2.67625307]) = 0.108
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.73824326  4.82689325]) = 3.981
# P(y=1| [-2.73824326  4.82689325]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.84636191  6.37581621]) = 1.109
# P(y=1| [-1.84636191  6.37581621]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.40034234  -3.73503447]) = 0.000
# P(y=1| [-10.40034234  -3.73503447]) = 7.067
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-3.45066092  3.65231838]) = 1.206
# P(y=1| [-3.45066092  3.65231838]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.25278459 -5.66880563]) = 0.000
# P(y=1| [-9.25278459 -5.66880563]) = 1.422
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.3024335   5.24154823]) = 4.449
# P(y=1| [-2.3024335   5.24154823]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-0.45494743  5.88160674]) = 1.319
# P(y=1| [-0.45494743  5.88160674]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.76635354  3.68128602]) = 5.948
# P(y=1| [-1.76635354  3.68128602]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.3502421   7.32379863]) = 0.109
# P(y=1| [-1.3502421   7.32379863]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.26240752 -2.5010788 ]) = 0.000
# P(y=1| [-9.26240752 -2.5010788 ]) = 2.178
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0.48240948 2.88649833]) = 0.273
# P(y=1| [0.48240948 2.88649833]) = 0.000
# Model predicted class 0 and the truth was 0
# P(y=0| [-0.43550148  4.86291211]) = 3.425
# P(y=1| [-0.43550148  4.86291211]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-8.26343176 -4.77889292]) = 0.000
# P(y=1| [-8.26343176 -4.77889292]) = 1.322
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.34192615  6.08790453]) = 1.506
# P(y=1| [-2.34192615  6.08790453]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.69436518  -2.35412905]) = 0.000
# P(y=1| [-10.69436518  -2.35412905]) = 1.747
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-3.01766137  6.85186791]) = 0.160
# P(y=1| [-3.01766137  6.85186791]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.2785846  3.6960324]) = 5.666
# P(y=1| [-1.2785846  3.6960324]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.03155531  -5.15730022]) = 0.000
# P(y=1| [-10.03155531  -5.15730022]) = 3.847
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.056524   4.7209218]) = 6.232
# P(y=1| [-1.056524   4.7209218]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.80965614  -3.0278945 ]) = 0.000
# P(y=1| [-10.80965614  -3.0278945 ]) = 3.691
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.90684913  -2.79237951]) = 0.000
# P(y=1| [-10.90684913  -2.79237951]) = 2.665
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.73151628  -3.77934447]) = 0.000
# P(y=1| [-10.73151628  -3.77934447]) = 5.883
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.04134032 -3.73594693]) = 0.000
# P(y=1| [-9.04134032 -3.73594693]) = 5.007
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.14319157  4.96913819]) = 5.877
# P(y=1| [-2.14319157  4.96913819]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.94557592 -4.81490993]) = 0.000
# P(y=1| [-9.94557592 -4.81490993]) = 5.461
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.95207008  -3.56161388]) = 0.000
# P(y=1| [-10.95207008  -3.56161388]) = 4.592
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.05327601  -5.91641975]) = 0.000
# P(y=1| [-11.05327601  -5.91641975]) = 0.665
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.85468424  -2.24329629]) = 0.000
# P(y=1| [-10.85468424  -2.24329629]) = 1.286
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.62657228  5.62420612]) = 2.328
# P(y=1| [-2.62657228  5.62420612]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.3255255   4.59954884]) = 7.241
# P(y=1| [-1.3255255   4.59954884]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-0.81869835  4.30360265]) = 5.531
# P(y=1| [-0.81869835  4.30360265]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.05249515  4.96377399]) = 5.596
# P(y=1| [-1.05249515  4.96377399]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.43013862 -4.02084046]) = 0.000
# P(y=1| [-9.43013862 -4.02084046]) = 6.792
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.71120328  -5.14603763]) = 0.000
# P(y=1| [-10.71120328  -5.14603763]) = 2.996
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.27009205 -4.30617962]) = 0.000
# P(y=1| [-9.27009205 -4.30617962]) = 5.794
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.63348508 -3.88275982]) = 0.000
# P(y=1| [-9.63348508 -3.88275982]) = 7.429
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-7.74756434 -5.99525408]) = 0.000
# P(y=1| [-7.74756434 -5.99525408]) = 0.087
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.3819777   -3.78942688]) = 0.000
# P(y=1| [-10.3819777   -3.78942688]) = 7.193
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.46683585  -5.75214768]) = 0.000
# P(y=1| [-10.46683585  -5.75214768]) = 1.418
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-0.70046592  5.06905752]) = 4.033
# P(y=1| [-0.70046592  5.06905752]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.89669814 -4.25722123]) = 0.000
# P(y=1| [-9.89669814 -4.25722123]) = 7.513
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.66466692  -2.98266578]) = 0.000
# P(y=1| [-10.66466692  -2.98266578]) = 3.945
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.73354292 -3.7543127 ]) = 0.000
# P(y=1| [-9.73354292 -3.7543127 ]) = 7.521
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.08047269  5.25100831]) = 4.653
# P(y=1| [-1.08047269  5.25100831]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-11.2468697   -3.54422284]) = 0.000
# P(y=1| [-11.2468697   -3.54422284]) = 3.292
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.69036122  5.98540377]) = 2.246
# P(y=1| [-1.69036122  5.98540377]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.52621728 -3.70869048]) = 0.000
# P(y=1| [-9.52621728 -3.70869048]) = 6.936
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.41832885 -4.97185151]) = 0.000
# P(y=1| [-9.41832885 -4.97185151]) = 4.046
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.53505096  -3.93584589]) = 0.000
# P(y=1| [-11.53505096  -3.93584589]) = 2.390
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.62152819 -5.16212522]) = 0.000
# P(y=1| [-9.62152819 -5.16212522]) = 3.597
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.10246182  -3.87151896]) = 0.000
# P(y=1| [-11.10246182  -3.87151896]) = 4.221
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.30884878  -5.21463059]) = 0.000
# P(y=1| [-10.30884878  -5.21463059]) = 3.404
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.14522335  -2.52306422]) = 0.000
# P(y=1| [-11.14522335  -2.52306422]) = 1.478
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.47104933  3.31915514]) = 3.113
# P(y=1| [-2.47104933  3.31915514]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.34451073  5.99505204]) = 2.118
# P(y=1| [-1.34451073  5.99505204]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.54231672  3.93621659]) = 6.925
# P(y=1| [-1.54231672  3.93621659]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.03714139  -5.44313842]) = 0.000
# P(y=1| [-10.03714139  -5.44313842]) = 2.629
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.59382447  -4.57909338]) = 0.000
# P(y=1| [-10.59382447  -4.57909338]) = 5.391
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.27611802  5.04828439]) = 5.212
# P(y=1| [-2.27611802  5.04828439]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.65846843  3.74979927]) = 3.817
# P(y=1| [-2.65846843  3.74979927]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.66099194  4.5197784 ]) = 7.708
# P(y=1| [-1.66099194  4.5197784 ]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.17504361  3.51520854]) = 4.708
# P(y=1| [-1.17504361  3.51520854]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.88343956  4.96475409]) = 3.158
# P(y=1| [-2.88343956  4.96475409]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.11062089  4.53957948]) = 6.686
# P(y=1| [-1.11062089  4.53957948]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-0.07169783  3.58197412]) = 1.661
# P(y=1| [-0.07169783  3.58197412]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.95412655 -4.93524526]) = 0.000
# P(y=1| [-9.95412655 -4.93524526]) = 4.895
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.65969406 -3.4919661 ]) = 0.000
# P(y=1| [-9.65969406 -3.4919661 ]) = 6.771
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.01909551  2.32979859]) = 0.760
# P(y=1| [-1.01909551  2.32979859]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.19473959  -3.78358319]) = 0.000
# P(y=1| [-10.19473959  -3.78358319]) = 7.609
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-8.98583076 -3.61697406]) = 0.000
# P(y=1| [-8.98583076 -3.61697406]) = 4.600
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.66694345 -4.93070165]) = 0.000
# P(y=1| [-9.66694345 -4.93070165]) = 4.688
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.89642852  4.27383692]) = 7.465
# P(y=1| [-1.89642852  4.27383692]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.70295951  4.92545924]) = 3.944
# P(y=1| [-2.70295951  4.92545924]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.26324119  4.72077776]) = 6.139
# P(y=1| [-2.26324119  4.72077776]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.7315193   4.50030817]) = 7.698
# P(y=1| [-1.7315193   4.50030817]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.98288758 -3.0558801 ]) = 0.000
# P(y=1| [-9.98288758 -3.0558801 ]) = 5.322
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.59347456  3.87346954]) = 4.366
# P(y=1| [-2.59347456  3.87346954]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0.16665927 5.5758025 ]) = 0.794
# P(y=1| [0.16665927 5.5758025 ]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.22337839  5.61493247]) = 3.440
# P(y=1| [-1.22337839  5.61493247]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.29873678  -4.03387924]) = 0.000
# P(y=1| [-10.29873678  -4.03387924]) = 7.479
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-7.99415331 -2.39679665]) = 0.000
# P(y=1| [-7.99415331 -2.39679665]) = 0.345
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.94872525  -3.32519699]) = 0.000
# P(y=1| [-10.94872525  -3.32519699]) = 4.093
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.6268016   3.55260879]) = 5.417
# P(y=1| [-1.6268016   3.55260879]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-8.16984786 -3.76643164]) = 0.000
# P(y=1| [-8.16984786 -3.76643164]) = 1.549
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-12.59372522  -5.21802923]) = 0.000
# P(y=1| [-12.59372522  -5.21802923]) = 0.123
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.76677678  -1.86620655]) = 0.000
# P(y=1| [-10.76677678  -1.86620655]) = 0.683
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-8.61896826 -4.1639871 ]) = 0.000
# P(y=1| [-8.61896826 -4.1639871 ]) = 3.106
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.18471127  -4.68314487]) = 0.000
# P(y=1| [-10.18471127  -4.68314487]) = 5.934
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.00998422  -4.55806635]) = 0.000
# P(y=1| [-10.00998422  -4.55806635]) = 6.579
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-8.96997584 -2.55363712]) = 0.000
# P(y=1| [-8.96997584 -2.55363712]) = 1.829
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.38389583  2.64324007]) = 1.614
# P(y=1| [-1.38389583  2.64324007]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.57427692  4.61981914]) = 7.564
# P(y=1| [-1.57427692  4.61981914]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.73363549  4.58074304]) = 7.613
# P(y=1| [-1.73363549  4.58074304]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.88927913  -3.60336828]) = 0.000
# P(y=1| [-10.88927913  -3.60336828]) = 4.942
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.26458576  -3.39527238]) = 0.000
# P(y=1| [-11.26458576  -3.39527238]) = 3.000
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.36174994  -4.68580454]) = 0.000
# P(y=1| [-11.36174994  -4.68580454]) = 2.355
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-8.66025539 -3.01171568]) = 0.000
# P(y=1| [-8.66025539 -3.01171568]) = 2.172
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.84679871 -2.38145976]) = 0.000
# P(y=1| [-9.84679871 -2.38145976]) = 2.327
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.73916309 -4.64398499]) = 0.000
# P(y=1| [-9.73916309 -4.64398499]) = 6.056
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-9.37956229 -3.66371391]) = 0.000
# P(y=1| [-9.37956229 -3.66371391]) = 6.354
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.45790348  5.89215285]) = 2.546
# P(y=1| [-1.45790348  5.89215285]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.75224597 -4.84877527]) = 0.000
# P(y=1| [-9.75224597 -4.84877527]) = 5.173
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0.16021318 4.74450678]) = 1.498
# P(y=1| [0.16021318 4.74450678]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.71013459  4.22145134]) = 7.618
# P(y=1| [-1.71013459  4.22145134]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.85806023  4.32588287]) = 7.570
# P(y=1| [-1.85806023  4.32588287]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.96793682  4.58015511]) = 3.272
# P(y=1| [-2.96793682  4.58015511]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.83198811  3.52863145]) = 5.220
# P(y=1| [-1.83198811  3.52863145]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-10.23209609  -4.22584668]) = 0.000
# P(y=1| [-10.23209609  -4.22584668]) = 7.368
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-2.04712429  4.06394521]) = 6.779
# P(y=1| [-2.04712429  4.06394521]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-9.83131334 -4.20557276]) = 0.000
# P(y=1| [-9.83131334 -4.20557276]) = 7.565
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-12.03845768  -4.65636011]) = 0.000
# P(y=1| [-12.03845768  -4.65636011]) = 0.762
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-1.54512233  3.57956458]) = 5.513
# P(y=1| [-1.54512233  3.57956458]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-2.87368912  5.21975133]) = 2.685
# P(y=1| [-2.87368912  5.21975133]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-1.15230832  4.28992244]) = 6.845
# P(y=1| [-1.15230832  4.28992244]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [-11.06770409  -3.61672206]) = 0.000
# P(y=1| [-11.06770409  -3.61672206]) = 4.163
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.69874071  -6.82139448]) = 0.000
# P(y=1| [-10.69874071  -6.82139448]) = 0.105
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-10.29075928  -4.44181676]) = 0.000
# P(y=1| [-10.29075928  -4.44181676]) = 6.680
# Model predicted class 1 and the truth was 1
#
# P(y=0| [-11.18279063  -4.81939513]) = 0.000
# P(y=1| [-11.18279063  -4.81939513]) = 2.662
# Model predicted class 1 and the truth was 1

# %% [markdown]
# First let's create a discrete dataset

# %%
X = np.where(X > 0, 1, 0)

# %%
print(X.shape, y.shape)
print(X[:5])
print(y[:5])
# Out:
# (10000, 2) (10000,)
# [[0 1]
#  [0 0]
#  [0 1]
#  [0 1]
#  [0 1]]
# [0 1 0 0 0]

# %%
nb = NaiveBayes(X, y, epsilon = 2, discrete = True)

# %%
nb.runModel()

# %%
nb.predict()
# Out:
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# ...
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [1 1]) = 2.596
# P(y=1| [1 1]) = 0.000
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 1]) = 47.047
# P(y=1| [0 1]) = 0.029
# Model predicted class 0 and the truth was 0
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
#
# P(y=0| [0 0]) = 0.027
# P(y=1| [0 0]) = 50.272
# Model predicted class 1 and the truth was 1
